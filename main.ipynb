# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from model import OpinionModel
import matplotlib.pyplot as plt

model = OpinionModel(num_agents=300)

knowledge = []
commitment_threshold = []
reputation = []

for agent in model.agents:
    knowledge.append(agent.knowledge)
    commitment_threshold.append(agent.involvement_threshold)
    reputation.append(agent.reputation)

plt.hist(knowledge, bins=10, label='Knowledge', edgecolor='black', linewidth=1.2)
plt.xlim(0, 1)
plt.title("Knowledge Distribution")
plt.show()
plt.hist(commitment_threshold, bins=10, label='Commitment Threshold', edgecolor='black', linewidth=1.2)
plt.title("Commitment Threshold Distribution")
plt.xlim(0, 1)

plt.show()
plt.hist(reputation, bins=10, label='Reputation', edgecolor='black', linewidth=1.2)
plt.title("Reputation Distribution")
plt.xlim(0, 1)
plt.show()


for i in range(50):
    model.step()

results = model.datacollector.get_model_vars_dataframe()
results.plot()
plt.title("Opinion Dynamics Over Time")
plt.xlabel("Step")
plt.ylabel("Number of Agents")
plt.grid(True)
plt.show()

for agent in model.agents:
    knowledge.append(agent.knowledge)
    commitment_threshold.append(agent.involvement_threshold)
    reputation.append(agent.reputation)

plt.hist(knowledge, bins=10, label='Knowledge', edgecolor='black', linewidth=1.2)
plt.xlim(0, 1)
plt.title("Knowledge Distribution")
plt.show()
plt.hist(commitment_threshold, bins=10, label='Commitment Threshold', edgecolor='black', linewidth=1.2)
plt.title("Commitment Threshold Distribution")
plt.xlim(0, 1)

plt.show()
plt.hist(reputation, bins=10, label='Reputation', edgecolor='black', linewidth=1.2)
plt.title("Reputation Distribution")
plt.xlim(0, 1)
plt.show()
# Out:
# Nodes: 300
# Edges: 788
# Average degree: 5.25
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 31
#      27 plt.show()
#      30 for i in range(50):
# ---> 31     model.step()
#      33 results = model.datacollector.get_model_vars_dataframe()
#      34 results.plot()
#
# File c:\Users\Norbert\anaconda3\envs\agents\Lib\site-packages\mesa\model.py:122, in Model._wrapped_step(self, *args, **kwargs)
#     120 _mesa_logger.info(f"calling model.step for timestep {self.steps} ")
#     121 # Call the original user-defined step method
# --> 122 self._user_step(*args, **kwargs)
#
# File c:\Users\Norbert\Desktop\AIDA\sem1\AgentSystem\model.py:39, in step(self)
#      37 for i, node in enumerate(self.G.nodes()):
#      38     knowledge = np.random.triangular(left=0, mode=0.05, right=1)
# ---> 39     opinion = 0
#      40     agent = OpinionAgent(i, self, knowledge, opinion)
#      41     if i == 30:
#
# File c:\Users\Norbert\anaconda3\envs\agents\Lib\site-packages\mesa\agent.py:345, in AgentSet.shuffle_do(self, method, *args, **kwargs)
#     343     for ref in weakrefs:
#     344         if (agent := ref()) is not None:
# --> 345             getattr(agent, method)(*args, **kwargs)
#     346 else:
#     347     for ref in weakrefs:
#
# File c:\Users\Norbert\Desktop\AIDA\sem1\AgentSystem\agent.py:21, in OpinionAgent.spread_step(self)
#      18 def spread_step(self):
#      19     # Share message if involved
#      20     if self.involvement >= self.involvement_threshold and self.opinion != 0:
# ---> 21         neighbor = self.random.choice(self.model.grid.get_neighbors(self.pos, include_center=False))
#      22         payload = self.opinion * self.reputation
#      23         neighbor.receive_payload(payload)
#
# File c:\Users\Norbert\anaconda3\envs\agents\Lib\random.py:347, in Random.choice(self, seq)
#     344 # As an accommodation for NumPy, we don't use "if not seq"
#     345 # because bool(numpy.array()) raises a ValueError.
#     346 if not len(seq):
# --> 347     raise IndexError('Cannot choose from an empty sequence')
#     348 return seq[self._randbelow(len(seq))]
#
# IndexError: Cannot choose from an empty sequence
